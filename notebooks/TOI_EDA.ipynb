# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
toi_df = pd.read_csv('.././data/processed/TOIProcessed.csv')

# %%
toi_df = toi_df.loc[:, toi_df.nunique() > 1]
toi_df
# Out:
#           toi        tid tfopwg_disp         rastr          ra         decstr  \
# 0     1000.01   50365310          FP  07h29m25.85s  112.357708  -12d41m45.46s
# 1     1001.01   88863718          PC  08h10m19.31s  122.580465  -05d30m49.87s
# 2     1004.01  238597883          FP  08h08m42.77s  122.178195  -48d48m10.12s
# 3     1007.01   65212867          PC  07h31m00.57s  112.752393  -04d27m48.09s
# 4     1011.01  114018671          PC  07h35m56.34s  113.984761   -32d50m31.2s
# ...       ...        ...         ...           ...         ...            ...
# 5139   993.01  259353953          PC   07h35m50.6s  113.960841  -15d29m58.04s
# 5140   994.01   93963408          FP  07h40m11.12s  115.046333  -09d05m03.37s
# 5141   997.01  341729521          FP  08h05m16.69s  121.319521  -59d34m47.27s
# 5142   998.01   54390047          FP  07h53m16.69s  118.319555  -14d13m07.76s
# 5143   999.01  341186896          FP  07h55m27.38s  118.864086  -58d13m19.42s
#
# ...

# %%
toi_df.st_pmralim.unique()
# Out:
# array([0.])

# %%
plt.figure(figsize=(16, 12))
sns.heatmap(toi_df.corr(numeric_only=True), annot=False, cmap='coolwarm')
plt.title('Heatmap de correlaciones TOI')
plt.show()
